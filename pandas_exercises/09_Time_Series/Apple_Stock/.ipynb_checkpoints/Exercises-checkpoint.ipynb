# %% [markdown]
# # Apple Stock

# %% [markdown]
# ### Introduction:
#
# We are going to use Apple's stock price.
#
#
# ### Step 1. Import the necessary libraries

# %%
#import libraries
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/09_Time_Series/Apple_Stock/appl_1980_2014.csv)

# %%
#import data
df=pd.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/09_Time_Series/Apple_Stock/appl_1980_2014.csv',sep=',')

# %% [markdown]
# ### Step 3. Assign it to a variable apple

# %%
#assign it to apple
apple=df

# %% [markdown]
# ### Step 4.  Check out the type of the columns

# %%
#checking the type of each column
apple.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8465 entries, 0 to 8464
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       8465 non-null   object
#  1   Open       8465 non-null   float64
#  2   High       8465 non-null   float64
#  3   Low        8465 non-null   float64
#  4   Close      8465 non-null   float64
#  5   Volume     8465 non-null   int64
#  6   Adj Close  8465 non-null   float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 463.1+ KB

# %% [markdown]
# ### Step 5. Transform the Date column as a datetime type

# %%
#changing the type of the date column
apple['Date']=apple['Date'].astype('datetime64[ns]')

# %% [markdown]
# ### Step 6.  Set the date as the index

# %%
#changing index
apple=apple.set_index('Date')

# %% [markdown]
# ### Step 7.  Is there any duplicate dates?

# %%
#checking for duplicates
apple.index.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Step 8.  Ops...it seems the index is from the most recent date. Make the first entry the oldest date.

# %%
#reindex the dates
apple=apple.reindex(apple.index.sort_values())

# %% [markdown]
# ### Step 9. Get the last business day of each month

# %%
#shows the last day in the month
apple.resample('M').last()
# Out:
#               Open    High     Low   Close     Volume  Adj Close
# Date
# 1980-12-31   34.25   34.25   34.13   34.13    8937600       0.53
# 1981-01-31   28.50   28.50   28.25   28.25   11547200       0.44
# 1981-02-28   26.50   26.75   26.50   26.50    3690400       0.41
# 1981-03-31   24.75   24.75   24.50   24.50    3998400       0.38
# 1981-04-30   28.38   28.62   28.38   28.38    3152800       0.44
# ...            ...     ...     ...     ...        ...        ...
# 2014-03-31  539.23  540.81  535.93  536.74   42167300      76.25
# 2014-04-30  592.64  599.43  589.80  590.09  114160200      83.83
# 2014-05-31  637.98  644.17  628.90  633.00  141005200      90.43
# 2014-06-30   92.10   93.73   92.09   92.93   49482300      92.93
# 2014-07-31   96.27   96.80   93.92   95.35   65130000      95.35
#
# [404 rows x 6 columns]

# %% [markdown]
# ### Step 10.  What is the difference in days between the first day and the oldest

# %%
#show the subtraction of the last day to the first day
apple.index[-1]-apple.index[0]
# Out:
# Timedelta('12261 days 00:00:00')

# %% [markdown]
# ### Step 11.  How many months in the data we have?

# %%
#counts how many months we have in the data
len(apple.resample('M'))
# Out:
# 404

# %% [markdown]
# ### Step 12. Plot the 'Adj Close' value. Set the size of the figure to 13.5 x 9 inches

# %%
#plot the adj close values
apple['Adj Close'].plot().get_figure().set_size_inches(13.5,9)

# %% [markdown]
# ### BONUS: Create your own question and answer it.

# %%
#describe every year (min, max , mean , std)
apple.groupby(apple.index.year).agg(['min','max','mean','std'])
# Out:
#         Open                                    High                      \
#          min     max        mean         std     min     max        mean
# Date
# 1980   25.37   36.00   30.481538    3.844498   25.37   36.13   30.567692
# 1981   14.38   34.50   24.386349    4.899738   14.50   34.75   24.471865
# 1982   11.12   33.87   19.139723    5.977608   11.12   34.88   19.412688
# 1983   17.88   62.75   37.524841   12.242139   19.25   63.25   38.376071
# 1984   22.63   33.25   26.869960    2.119966   22.75   34.38   27.393755
# 1985   14.62   30.63   20.378814    4.573970   14.75   31.12   20.595178
# 1986   22.00   43.63   32.387391    5.538581   22.25   43.87   32.938498
# 1987   29.50   80.50   53.822688   14.438085   31.25   82.25   55.036443
# 1988   35.75   47.13   41.555889    2.511109   36.75   47.75   42.186364
# 1989   33.75   49.75   41.615000    4.104909   34.50   50.38   42.300238
# 1990   25.25   47.50   37.502016    4.584947   26.50   47.75   38.219486
# ...
